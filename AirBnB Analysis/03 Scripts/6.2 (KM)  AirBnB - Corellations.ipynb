# %% [markdown]
# # 1. Importing Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Check matplotlib version

matplotlib.__version__
# Out:
# '3.7.0'

# %%
# import data

# %%
path = r'C:\Users\Lenovo\AirBnB Analysis\02 Data'

# %%
df= pd.read_pickle(os.path.join(path, 'Prepared Data','AirBnB_all.pkl'),)

# %%
# Check

# %%
df.head()
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      1    0                10.0  ...
# 1              4.0              False      0    0                 8.0  ...
# 2              2.0              False      0    1                 9.0  ...
# 3              4.0              False      0    1                 9.0  ...
# 4              2.0               True      0    0                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
df.shape
# Out:
# (51707, 22)

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# realSum                       float64
# room_type                      object
# room_shared                      bool
# room_private                     bool
# person_capacity               float64
# host_is_superhost                bool
# multi                           int64
# biz                             int64
# cleanliness_rating            float64
# guest_satisfaction_overall    float64
# bedrooms                        int64
# dist                          float64
# metro_dist                    float64
# attr_index                    float64
# attr_index_norm               float64
# rest_index                    float64
# rest_index_norm               float64
# lng                           float64
# lat                           float64
# City                           object
# WeekTime                       object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'realSum', 'room_type', 'room_shared', 'room_private',
#        'person_capacity', 'host_is_superhost', 'multi', 'biz',
#        'cleanliness_rating', 'guest_satisfaction_overall', 'bedrooms', 'dist',
#        'metro_dist', 'attr_index', 'attr_index_norm', 'rest_index',
#        'rest_index_norm', 'lng', 'lat', 'City', 'WeekTime'],
#       dtype='object')

# %% [markdown]
# # 2. Picking out variables suitable for the exploratory visual analysis.

# %% [markdown]
# Questions to Explore:
# What influences prices the most:
# Cleanness?
# Number of bedrooms?
# Room capacity?
# Room privacy?
# Guess satisfaction?
# Location?
#
# What are the most / least expensive cities? Why?
# What factors have the most impact on the price of AirBnB?
# Do prices differ on weekends and weekdays?

# %%
# creating relevant subsets

# %%
df_estate = df[['realSum',  'room_shared', 'room_private',
       'person_capacity','bedrooms', 'dist', 
       'metro_dist']]

# %%
df_host = df[['realSum', 'host_is_superhost', 'cleanliness_rating', 'guest_satisfaction_overall']]

# %% [markdown]
# # 3. Create a correlation matrix heatmap (colored).

# %%
# Creating correlation matrix

# %%
df.corr()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15460\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                             Unnamed: 0   realSum  room_shared  room_private  \
# Unnamed: 0                    1.000000  0.010863    -0.003336      0.039880
# realSum                       0.010863  1.000000    -0.035095     -0.171949
# room_shared                  -0.003336 -0.035095     1.000000     -0.063533
# room_private                  0.039880 -0.171949    -0.063533      1.000000
# person_capacity              -0.001816  0.203077     0.035146     -0.499993
# host_is_superhost            -0.059890 -0.045478    -0.027839     -0.049501
# multi                        -0.001999 -0.052926    -0.016061      0.137026
# ...

# %%
df_estate.corr()
# Out:
#                   realSum  room_shared  room_private  person_capacity  \
# realSum          1.000000    -0.035095     -0.171949         0.203077
# room_shared     -0.035095     1.000000     -0.063533         0.035146
# room_private    -0.171949    -0.063533      1.000000        -0.499993
# person_capacity  0.203077     0.035146     -0.499993         1.000000
# bedrooms         0.221653    -0.021365     -0.155889         0.560627
# dist            -0.044725     0.014144      0.213351        -0.128488
# metro_dist      -0.061025    -0.002868      0.101981        -0.037267
#
#                  bedrooms      dist  metro_dist
# realSum          0.221653 -0.044725   -0.061025
# room_shared     -0.021365  0.014144   -0.002868
# room_private    -0.155889  0.213351    0.101981
# person_capacity  0.560627 -0.128488   -0.037267
# bedrooms         1.000000 -0.006262    0.044431
# dist            -0.006262  1.000000    0.558064
# metro_dist       0.044431  0.558064    1.000000

# %%
df_host.corr()
# Out:
#                              realSum  host_is_superhost  cleanliness_rating  \
# realSum                     1.000000          -0.045478           -0.006082
# host_is_superhost          -0.045478           1.000000            0.272376
# cleanliness_rating         -0.006082           0.272376            1.000000
# guest_satisfaction_overall -0.001888           0.280062            0.714045
#
#                             guest_satisfaction_overall
# realSum                                      -0.001888
# host_is_superhost                             0.280062
# cleanliness_rating                            0.714045
# guest_satisfaction_overall                    1.000000

# %%
# Creating correlation heatmaps

# %%
plt.matshow(df.corr())
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15460\2438265331.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(df.corr())

# %%
plt.matshow(df_estate.corr())
plt.show()

# %%
plt.matshow(df_host.corr())
plt.show()

# %%
#current dir
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\Lenovo\\AirBnB Analysis\\03 Scripts'

# %%
# Adding labels, legend, and changing the size of the heatmap

# %%
f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df_estate.corr(), fignum=f.number) # type of plot
plt.xticks(range(df_estate.shape[1]), df_estate.columns, fontsize=11, rotation=90) # x axis labels
plt.yticks(range(df_estate.shape[1]), df_estate.columns, fontsize=11) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df_host.corr(), fignum=f.number) # type of plot
plt.xticks(range(df_host.shape[1]), df_host.columns, fontsize=11, rotation=90) # x axis labels
plt.yticks(range(df_host.shape[1]), df_host.columns, fontsize=11) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Creating  correlation matrix heatmap in seaborn

# %%
# Creating a subplot with matplotlib

# %%
# Creating the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined.
f,ax = plt.subplots(figsize=(10,10))
# Creating the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df_estate.corr(), annot = True, ax = ax)

# %%
# Creating the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined.
f,ax = plt.subplots(figsize=(10,10))
# Creating the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df_host.corr(), annot = True, ax = ax)

# %%
# Creating subplot with matplotlib
f,ax = plt.subplots(figsize=(20,20))

# Creating correlation heatmap in seaborn for all columns just for checking
corr = sns.heatmap(df.corr(), annot = True, ax = ax)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15460\930710529.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = sns.heatmap(df.corr(), annot = True, ax = ax)

# %%
df_satisfaction = df[['guest_satisfaction_overall','realSum',  'room_shared', 'room_private',
       'person_capacity','bedrooms', 'dist','metro_dist']]

# %%
# Creating subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Creating correlation heatmap in seaborn for subset 
corr = sns.heatmap(df_satisfaction.corr(), annot = True, ax = ax)

# %% [markdown]
# The only significant correlation I can spot is happening between guest satisfation and cleanliness. I do not see any corellation that would suggest what influences the price.

# %% [markdown]
# # 4. Create a scatterplot (or plots) for the variables with the strongest correlations and examine the nature of their relationships.

# %%
# Creating a scatterplot in seaborn

sns.lmplot(x = 'guest_satisfaction_overall', y = 'cleanliness_rating', data = df)

# %% [markdown]
# It seems that cleanliness rating correlate very strongly with overall guests satisfaction. We can conclude that cleanliness is important for guests.

# %% [markdown]
# # 5. Create a pair plot of the entire data set.

# %%
# creating a subset

# %%
df_feat = df[['realSum',  'room_shared', 'room_private', 'person_capacity','bedrooms', 'dist', 
                'host_is_superhost', 'cleanliness_rating', 'guest_satisfaction_overall', 'metro_dist']]

# %%
# Creating pairs for subsets

g = sns.pairplot(df_host)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
g = sns.pairplot(df_estate)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
g = sns.pairplot(df_satisfaction)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %% [markdown]
# Seems that more customers are very satisfied when distance to metro and to city center are short and the price is low. There is no indication what determines the price of the place and not much dependencies overall. I suppose it would be valuable to break the data set into the cities and compare then among each other as well as compare weekdays to weekends.

# %% [markdown]
# # 6. Create a categorical plot and interpret the results.

# %%
sns.histplot(df['guest_satisfaction_overall'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='guest_satisfaction_overall', ylabel='Count'>

# %%
df.loc[df['guest_satisfaction_overall'] < 60, 'satisfaction'] = 'Unsatisfied'

# %%
df.loc[(df['guest_satisfaction_overall'] >= 60) & (df['guest_satisfaction_overall'] < 90), 'satisfaction'] = 'Satisfied'

# %%
df.loc[df['guest_satisfaction_overall'] >= 90, 'satisfaction'] = 'Very Satisfied'

# %%
# checking column

df['satisfaction'].value_counts(dropna = False)
# Out:
# Very Satisfied    39816
# Satisfied         11586
# Unsatisfied         305
# Name: satisfaction, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'realSum', 'room_type', 'room_shared', 'room_private',
#        'person_capacity', 'host_is_superhost', 'multi', 'biz',
#        'cleanliness_rating', 'guest_satisfaction_overall', 'bedrooms', 'dist',
#        'metro_dist', 'attr_index', 'attr_index_norm', 'rest_index',
#        'rest_index_norm', 'lng', 'lat', 'City', 'WeekTime', 'satisfaction'],
#       dtype='object')

# %%
# Creating categorical plot in seaborn

# %%
sns.set(style="ticks")
g = sns.catplot(x="cleanliness_rating", y="guest_satisfaction_overall", hue="satisfaction", data=df)

# %% [markdown]
# Even though there are unsatisfied guests across all cleanliness levels, Satisfied  and very satisfied guests occur way more often when the cleanliness is above 6.

# %%
# fig = g.get_figure()
g.savefig("out.png")

# %% [markdown]
# # 7. Revisit the questions you generated in the previous task and write answers to those you can based on the exploration you’ve conducted so far.

# %% [markdown]
# ### What influences prices the most: Cleanness? Number of bedrooms? Room capacity? Room privacy? Guess satisfaction? Location?
#
# ### What are the most / least expensive cities? Why? What factors have the most impact on the price of AirBnB? Do prices differ on weekends and weekdays?

# %% [markdown]
# There seem to be no one, important defining factor for the price. None of available variables were proven to significantly influence the price. Next steps shall be focused on finding dependencies in individual cieties and weekends to weekdays.

# %% [markdown]
# # 8. Define any hypotheses that you can at this point.

# %% [markdown]
# There is no one hypothesis I can define at this point. Data so far did not bring any answers over that there no single factor that determines the price. Posibly looking in indiwidual cities or days of the week will bring more information.

# %%
df.to_csv(os.path.join(path,'AirBnB_all_set.csv'))
